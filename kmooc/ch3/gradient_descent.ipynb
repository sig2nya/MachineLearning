# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def f1(x):
  return 3*x**2 + 6*x + 1

# %%
def f1d(x):
  return 6*x + 6

# %%
xx = np.linspace(-4, 2, 200) #linear space

# %%
step_size = 0.1

plt.plot(xx, f1(xx), '--k')

x = -3
plt.plot(x, f1(x), 'go', markersize = 10)
plt.text(x + 0.2, f1(x) + 0.1, "start")
plt.plot(xx, f1d(x) * (xx - x) + f1(x), 'b--')
print("start : x_0={}, g_0={}".format(x, f1d(x)))

x = x - step_size * f1d(x)
plt.plot(x, f1(x), 'go', markersize = 10)
plt.text(x + 0.2, f1(x) + 0.1, "x_1")
plt.plot(xx, f1d(x) * (xx - x) + f1(x), 'b--')
print("x_1 : x_1={}, g_1={}".format(x, f1d(x)))

x = x - step_size * f1d(x)
plt.plot(x, f1(x), 'go', markersize = 10)
plt.text(x + 0.2, f1(x) + 0.1, "x_2")
plt.plot(xx, f1d(x) * (xx - x) + f1(x), 'b--')
print("x_2 : x_2={}, g_2={}".format(x, f1d(x)))

plt.ylim(-5, 15)
plt.xlabel('x')
plt.grid(True)
plt.show()
# Out:
# start : x_0=-3, g_0=-12
# x_1 : x_1=-1.7999999999999998, g_1=-4.799999999999999
# x_2 : x_2=-1.3199999999999998, g_2=-1.919999999999999

# %%
step_size = 0.3 # step size -> 즉 람다 폭을 매우 크게 주면, model이 최적화 함수를 찾는데 오래 걸릴 것이다.

plt.plot(xx, f1(xx), '--k')

x = -3
plt.plot(x, f1(x), 'go', markersize = 10)
plt.text(x + 0.2, f1(x) + 0.1, "start")
plt.plot(xx, f1d(x) * (xx - x) + f1(x), 'b--')
print("start : x_0={}, g_0={}".format(x, f1d(x)))

x = x - step_size * f1d(x)
plt.plot(x, f1(x), 'go', markersize = 10)
plt.text(x + 0.2, f1(x) + 0.1, "x_1")
plt.plot(xx, f1d(x) * (xx - x) + f1(x), 'b--')
print("x_1 : x_1={}, g_1={}".format(x, f1d(x)))

x = x - step_size * f1d(x)
plt.plot(x, f1(x), 'go', markersize = 10)
plt.text(x + 0.2, f1(x) + 0.1, "x_2")
plt.plot(xx, f1d(x) * (xx - x) + f1(x), 'b--')
print("x_2 : x_2={}, g_2={}".format(x, f1d(x)))

plt.ylim(-5, 15)
plt.xlabel('x')
plt.grid(True)
plt.show()
# Out:
# start : x_0=-3, g_0=-12
# x_1 : x_1=0.5999999999999996, g_1=9.599999999999998
# x_2 : x_2=-2.28, g_2=-7.68
